# %% [markdown]
# # 8.5.1 Varimax Rotation (Orthogonal)

# %%
# Perform Varimax rotation
perform_factor_analysis(data, 'varimax')

# %% [markdown]
# # 8.5.2 Oblimin Rotation (Oblique)

# %%
# Perform Oblimin rotation
perform_factor_analysis(data, 'oblimin')

# %% [markdown]
# # 8.5.3 Promax Rotation (Oblique)

# %%
# Perform Promax rotation
perform_factor_analysis(data, 'promax')
